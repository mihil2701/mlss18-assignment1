# %%
import pandas as pd
from matplotlib import pyplot as plt
import matplotlib
import numpy as np
df = pd.DataFrame(np.arange(12).reshape(3,4),columns=['A', 'B', 'C', 'D'])

# %%
df
# Out:
#    A  B   C   D
# 0  0  1   2   3
# 1  4  5   6   7
# 2  8  9  10  11

# %%
matplotlib.rc('figure', figsize = (14, 7))
matplotlib.rc('font',size=15)
ax=plt.subplot(111)
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
ax.plot(df)
plt.show()

# %%
def histogram(data, x_label, y_label, title):
    fig,ax=plt.subplots()
    ax.hist(data,alpha=0.75)
    ax.set_title(title)
    ax.set_xlabel(x_label)
    ax.set_ylabel(y_label)
#Calling the function "histogram"
histogram(data = df
           , x_label = 'Check outs'
           , y_label = 'Frequency'
           , title = 'Distribution of Registered Check Outs')
plt.show()

# %%
x_data=[1,2,3,4]
y1=[10,20,30,40]
y2=[5,10,15,20]
fig,ax=plt.subplots()
ax.plot(x_data,y1,x_data,y2)
ax.set_xlabel('mihil')
ax.set_ylabel('1')
plt.legends[[]]
plt.show()
